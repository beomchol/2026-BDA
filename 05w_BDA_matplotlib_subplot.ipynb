# %% [markdown]
# <a href="https://colab.research.google.com/github/beomchol/2026-BDA/blob/main/05w_BDA_matplotlib_subplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Koreanize-matplotlib

# %%
# Ensure Korean fonts are installed and update font caches
# !sudo apt-get update -qq
# !sudo apt-get install -y fonts-nanum > /dev/null
# !sudo fc-cache -fv

# Import matplotlib and koreanize_matplotlib to automatically apply Korean fonts
import matplotlib.pyplot as plt
import koreanize_matplotlib

# Keep unicode_minus setting as it's a good practice for Korean plotting
plt.rc('axes', unicode_minus = False)

# Note: After running this cell, a runtime restart (Runtime -> Restart runtime)
# is highly recommended for matplotlib to fully pick up the new fonts and configurations.
# If Korean characters still don't display correctly, please restart the runtime
# and then re-execute all cells in order.
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([10, 5, 25, 30, 20])
plt.title('직선 그래프 그리기: 한글처리')
plt.show()

# %%
import numpy as np

x = np.random.randint(-10, 10, 10)

print(x)
print(x > 0)
print(x[x > 0])
# Out:
# [ 9  8 -3 -3 -6 -4 -6 -9  4 -9]
# [ True  True False False False False False False  True False]
# [9 8 4]

# %%
plt.bar(["Red", "Green", "Blue"], [8, 5, 10])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.suptitle('전체 제목', fontsize = 14, y=1.02)
plt.subplot(2, 3, 1)
plt.plot([1, 4, 9, 16])
plt.title('제곱수')

plt.subplot(2, 3, 6)
plt.plot([6, 5, 2, 1])
plt.title('감소')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np

age = pd.Series([9, 17, 32, 45, 65, 98], index=list('abcdef'), name='age')
age
# Out:
# a     9
# b    17
# c    32
# d    45
# e    65
# f    98
# Name: age, dtype: int64

# %%
int(age['b'])
# Out:
# 17

# %%
age[[1, 3, 5]]
# Out:
# /tmp/ipykernel_60129/1546391730.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age[[1, 3, 5]]
# b    17
# d    45
# f    98
# Name: age, dtype: int64

# %%
age[['a', 'f', 'd']]
# Out:
# a     9
# f    98
# d    45
# Name: age, dtype: int64

# %%
age[['c']]
# Out:
# c    32
# Name: age, dtype: int64
